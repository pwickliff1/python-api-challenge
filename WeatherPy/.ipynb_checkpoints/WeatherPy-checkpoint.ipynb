# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Open Weather url
url = "http://api.openweathermap.org/data/2.5/weather?"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %%
#TEST REMOVE
city = "London"
query_url = url + "appid=" + weather_api_key + "&q=" + city
    # Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Initialize variables
rec = 1
sets = 1
city_name = []
country = []
date = []
humid = []
lat = []
lon = []
max_temp = []
wind_speed = []
clouds = []

# Print report header
print("Beginning Data Retrieval")     
print("-----------------------------")

# Built target lists
for city in cities:
    # Build query URL based on current element in units
    #query_url = url + "appid=" + api_key + "&q=" + city + "&units=" + unit
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()     
    
   
    # Print weather data
    try:
        print(f"Processing Record {rec} of {sets} | {weather_json['name']}")
        
        # Load lists with weater data
        city_name.append(weather_json['name'])
        clouds.append(weather_json['clouds']['all'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
        humid.append(weather_json['main']['humidity'])
        lat.append(weather_json['coord']['lat'])
        lon.append(weather_json['coord']['lon'])
        max_temp.append(weather_json['main']['temp_max'])
        wind_speed.append(weather_json['wind']['speed'])
        
        if rec == 50:
          rec = 0
          sets += 1
        else:
          rec += 1
    except KeyError: 
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of 1 | Rikitea
# Processing Record 2 of 1 | Jesup
# Processing Record 3 of 1 | Dikson
# Processing Record 4 of 1 | Mar del Plata
# Processing Record 5 of 1 | Luena
# Processing Record 6 of 1 | Saskylakh
# Processing Record 7 of 1 | Virginia Beach
# City not found. Skipping...
# Processing Record 8 of 1 | Fare
# Processing Record 9 of 1 | Marinhas
# Processing Record 10 of 1 | Zhezkazgan
# Processing Record 11 of 1 | Bambous Virieux
# Processing Record 12 of 1 | Albany
# Processing Record 13 of 1 | Anadyr
# Processing Record 14 of 1 | Tiksi
# Processing Record 15 of 1 | Atuona
# Processing Record 16 of 1 | Pevek
# Processing Record 17 of 1 | Dingle
# Processing Record 18 of 1 | Zhigansk
# Processing Record 19 of 1 | Tessalit
# Processing Record 20 of 1 | Vermilion
# Processing Record 21 of 1 | Sambava
# Processing Record 22 of 1 | Vila Velha
# Processing Record 23 of 1 | Saint George
# City not found. Skipping...
# Processing Record 24 of 1 | East London
# Processing Record 25 of 1 | Carnarvon
# Processing Record 26 of 1 | Sovetskaya Gavan'
# Processing Record 27 of 1 | Gelemso
# Processing Record 28 of 1 | Kaitangata
# Processing Record 29 of 1 | Torbay
# Processing Record 30 of 1 | Cherskiy
# Processing Record 31 of 1 | Yellowknife
# Processing Record 32 of 1 | Beloha
# Processing Record 33 of 1 | Rudnogorsk
# Processing Record 34 of 1 | Punta Arenas
# Processing Record 35 of 1 | Arraial do Cabo
# Processing Record 36 of 1 | Avarua
# Processing Record 37 of 1 | San Quintín
# Processing Record 38 of 1 | Thompson
# Processing Record 39 of 1 | Coquimbo
# Processing Record 40 of 1 | Ponta do Sol
# Processing Record 41 of 1 | Busselton
# Processing Record 42 of 1 | Ust-Maya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 
# Processing Record 47 of 4 | Āgaro
# Processing Record 48 of 4 | Bourail
# Processing Record 49 of 4 | Port-Gentil
# Processing Record 50 of 4 | Ponta Delgada
# Processing Record 0 of 5 | Havre-St-Pierre
# Processing Record 1 of 5 | Richards Bay
# Processing Record 2 of 5 | Wamba
# Processing Record 3 of 5 | Gumlā
# Processing Record 4 of 5 | Tefé
# Processing Record 5 of 5 | Hong Kong
# Processing Record 6 of 5 | Racine
# Processing Record 7 of 5 | Nanortalik
# Processing Record 8 of 5 | Pacific Grove
# Processing Record 9 of 5 | Karratha
# Processing Record 10 of 5 | Sioux Lookout
# City not found. Skipping...
# Processing Record 11 of 5 | Mount Gambier
# Processing Record 12 of 5 | Mukhen
# Processing Record 13 of 5 | Vanimo
# Processing Record 14 of 5 | Alice Springs
# Processing Record 15 of 5 | São Filipe
# Processing Record 16 of 5 | Río Blanco
# Processing Record 17 of 5 | Deputatsky
# Processing Record 18 of 5 | Airai
# Processing Record 19 of 5 | Bengkulu
# Processing Record 20 of 5 | Sterling
# Processing Record 21 of 5 | Kahului
# Processing Record 22 of 5 | Balkanabat
# Processing Record 23 of 5 | Salamiyah
# Processing Record 24 of 5 | Acapulco de Juárez
# Processing Record 25 of 5 | Paso de los Toros
# Processing Record 26 of 5 | Khojaly District
# Processing Record 27 of 5 | Lázaro Cárdenas
# Processing Record 28 of 5 | Narsaq
# Processing Record 29 of 5 | Magugu
# Processing Record 30 of 5 | Mitha Tiwana
# Processing Record 31 of 5 | Beringovskiy
# Processing Record 32 of 5 | Erenhot
# Processing Record 33 of 5 | Abhā
# City not found. Skipping...
# Processing Record 34 of 5 | Morón
# Processing Record 35 of 5 | Impfondo
# Processing Record 36 of 5 | Tamandaré
# Processing Record 37 of 5 | Ndélé
# Processing Record 38 of 5 | Ahipara
# Processing Record 39 of 5 | Campos Altos
# Processing Record 40 of 5 | Itoman
# Processing Record 41 of 5 | Hambantota
# Processing Record 42 of 5 | Henties Bay
# Processing Record 43 of 5 | Maceió
# Processing Record 44 of 5 | Yinchuan
# Processing Record 45 of 5 | Ternate
# Processing Record 46 of 5 | Akdepe
# Processing Record 47 of 5 | Tindwāri
# Processing Record 48 of 5 | Mangan
# Processing Record 49 of 5 | Souillac
# Processing Record 50 of 5 | Namtsy
# Processing Record 0 of 6 | Yambio
# City not found. Skipping...
# Processing Record 1 of 6 | Bereda
# Processing Record 2 of 6 | Petrovsk-Zabaykal'skiy
# Processing Record 3 of 6 | Aras
# Processing Record 4 of 6 | Skibbereen
# City not found. Skipping...
# Processing Record 5 of 6 | Perehonivka
# Processing Record 6 of 6 | Amahai
# Processing Record 7 of 6 | Caravelas
# Processing Record 8 of 6 | Battle Creek
# Processing Record 9 of 6 | Challakere
# Processing Record 10 of 6 | Manyana
# Processing Record 11 of 6 | Bom Jardim
# Processing Record 12 of 6 | Oddur
# Processing Record 13 of 6 | Yayva
# Processing Record 14 of 6 | Padang
# Processing Record 15 of 6 | Half Moon Bay
# City not found. Skipping...
# Processing Record 16 of 6 | Ust-Nera
# Processing Record 17 of 6 | Jiaocheng
# Processing Record 18 of 6 | Salalah
# Processing Record 19 of 6 | Olafsvik
# Processing Record 20 of 6 | San Jorge
# City not found. Skipping...
# Processing Record 21 of 6 | Ituaçu
# Processing Record 22 of 6 | Provideniya
# Processing Record 23 of 6 | Mocuba
# City not found. Skipping...
# Processing Record 24 of 6 | Maryville
# Processing Record 25 of 6 | Galesong
# Processing Record 26 of 6 | San Cristobal
# Processing Record 27 of 6 | Shenjiamen
# Processing Record 28 of 6 | Mt. Pleasant
# Processing Record 29 of 6 | Zaozyornoye
# Processing Record 30 of 6 | Imeni Poliny Osipenko
# Processing Record 31 of 6 | Acaraú
# Processing Record 32 of 6 | Escanaba
# Processing Record 33 of 6 | Lata
# City not found. Skipping...
# Processing Record 34 of 6 | Potchefstroom
# Processing Record 35 of 6 | Crixás
# Processing Record 36 of 6 | Muros
# Processing Record 37 of 6 | Aksu
# Processing Record 38 of 6 | ‘Āhuimanu
# Processing Record 39 of 6 | Lagoa
# Processing Record 40 of 6 | Burnie
# Processing Record 41 of 6 | Baillif
# Processing Record 42 of 6 | Heinola
# Processing Record 43 of 6 | Baharly
# Processing Record 44 of 6 | Husavik
# Processing Record 45 of 6 | Cassilândia
# Processing Record 46 of 6 | Petropavlovsk-Kamchatskiy
# Processing Record 47 of 6 | Walvis Bay
# Processing Record 48 of 6 | Morro Bay
# Processing Record 49 of 6 | Turbat
# Processing Record 50 of 6 | Imeni Zhelyabova
# Processing Record 0 of 7 | Buloh Kasap
# City not found. Skipping...
# Processing Record 1 of 7 | Santiago de Cuba
# Processing Record 2 of 7 | Meulaboh
# Processing Record 3 of 7 | Kadiri
# Processing Record 4 of 7 | Kumul
# Processing Record 5 of 7 | Teacapan
# Processing Record 6 of 7 | Grahamstown
# Processing Record 7 of 7 | Fort Collins
# Processing Record 8 of 7 | Ukiah
# Processing Record 9 of 7 | Byron Bay
# City not found. Skipping...
# Processing Record 10 of 7 | Urengoy
# Processing Record 11 of 7 | Ābyek
# Processing Record 12 of 7 | Dossor
# Processing Record 13 of 7 | Province of Trapani
# Processing Record 14 of 7 | Río Gallegos
# Processing Record 15 of 7 | Baghdad
# Processing Record 16 of 7 | Artesia
# Processing Record 17 of 7 | Marsh Harbour
# Processing Record 18 of 7 | Dafeng
# Processing Record 19 of 7 | Penha
# City not found. Skipping...
# Processing Record 20 of 7 | Griffith
# Processing Record 21 of 7 | Bloomington
# Processing Record 22 of 7 | Baní
# Processing Record 23 of 7 | Turukhansk
# Processing Record 24 of 7 | Talnakh
# Processing Record 25 of 7 | Arlit
# City not found. Skipping...
# Processing Record 26 of 7 | Kalmunai
# City not found. Skipping...
# Processing Record 27 of 7 | Władysławowo
# Processing Record 28 of 7 | Geilo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of 7 | Tiarei
# Processing Record 30 of 7 | Yangi Marg`ilon
# Processing Record 31 of 7 | Norman Wells
# Processing Record 32 of 7 | Wau
# Processing Record 33 of 7 | Forsytheganj
# Processing Record 34 of 7 | Eureka
# Processing Record 35 of 7 | Kavaratti
# Processing Record 36 of 7 | Barcelos
# Processing Record 37 of 7 | Kenai
# Processing Record 38 of 7 | Rio Casca
# Processing Record 39 of 7 | Ribeira Grande
# Processing Record 33 of 10 | Oktyabr'skoye
# Processing Record 34 of 10 | Zambezi
# Processing Record 35 of 10 | Nikki
# Processing Record 36 of 10 | Udachny
# Processing Record 37 of 10 | Sosnovo-Ozerskoye
# Processing Record 38 of 10 | Monte Alegre de Sergipe
# Processing Record 39 of 10 | St. Pete Beach
# Processing Record 40 of 10 | Bilibino
# Processing Record 41 of 10 | Muskogee
# Processing Record 42 of 10 | Vila
# Processing Record 43 of 10 | Namatanai
# Processing Record 44 of 10 | Dongsheng
# Processing Record 45 of 10 | Angoche
# Processing Record 46 of 10 | Somanda
# Processing Record 47 of 10 | Sittwe
# Processing Record 48 of 10 | Sandnessjøen
# Processing Record 49 of 10 | Nhulunbuy
# Processing Record 50 of 10 | Diamantino
# Processing Record 0 of 11 | Thinadhoo
# Processing Record 1 of 11 | Severo-Kuril'sk
# Processing Record 2 of 11 | Tataouine
# Processing Record 3 of 11 | Segovia
# Processing Record 4 of 11 | Iqaluit
# Processing Record 5 of 11 | Amazar
# Processing Record 6 of 11 | Scarborough
# Processing Record 7 of 11 | Vila do Maio
# Processing Record 8 of 11 | Porto-Novo
# Processing Record 9 of 11 | Río Cuarto
# Processing Record 10 of 11 | Maryborough
# Processing Record 11 of 11 | Santa Maria
# Processing Record 12 of 11 | Junction City
# Processing Record 13 of 11 | Cabimas
# Processing Record 14 of 11 | Vao
# Processing Record 15 of 11 | Panalingaan
# Processing Record 16 of 11 | Hasaki
# Processing Record 17 of 11 | Christchurch
# Processing Record 18 of 11 | Coahuayana Viejo
# Processing Record 19 of 11 | Ancud
# Processing Record 20 of 11 | Opuwo
# Processing Record 21 of 11 | Nuuk
# Processing Record 22 of 11 | Dondo
# Processing Record 23 of 11 | Pimenteiras
# City not found. Skipping...
# Processing Record 24 of 11 | Mazyr
# Processing Record 25 of 11 | Te Anau
# Processing Record 26 of 11 | Havøysund
# Processing Record 27 of 11 | Mitsamiouli
# Processing Record 28 of 11 | Maniitsoq
# Processing Record 29 of 11 | Pryvillya
# Processing Record 30 of 11 | Zheshart
# Processing Record 31 of 11 | Mehamn
# Processing Record 32 of 11 | Tshane
# Processing Record 33 of 11 | Tocopilla
# Processing Record 34 of 11 | Luján
# Processing Record 35 of 11 | Waipawa
# Processing Record 36 of 11 | Martin
# Processing Record 37 of 11 | Arkhara
# Processing Record 38 of 11 | Kemijärvi
# Processing Record 39 of 11 | Gizo Government Station
# Processing Record 40 of 11 | Lorengau
# City not found. Skipping...
# Processing Record 41 of 11 | Bartica
# Processing Record 42 of 11 | Waingapu
# Processing Record 43 of 11 | Walla Walla
# Processing Record 44 of 11 | Oudtshoorn
# Processing Record 45 of 11 | Challapata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert weather data to dataframe

weather_pd = pd.DataFrame({
                            "City": city_name,
                            "Cloudiness": clouds,
                            "Country": country,
                            "Date": date,
                            "Humidity": humid,
                            "Lat": lat,
                            "Lon": lon,
                            "Max Temp": max_temp,
                            "Max Temp K": max_temp,
                            "Wind Speed": wind_speed
                          })

# Give index a name and change Temp to float
weather_pd.index.name = 'City_ID'
weather_pd["Max Temp"] = round(((weather_pd["Max Temp"].astype(float)*1.80 )- 459.67),0).astype(int)

# Create and export csv file
weather_pd.to_csv(output_data_file)

# Display dataframe
weather_pd.head(5)
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# City_ID
# 0              Rikitea          28      PF  1593137497        85 -23.12
# 1                Jesup           1      US  1593137497        69  31.61
# 2               Dikson         100      RU  1593137497        94  73.51
# 3        Mar del Plata           0      AR  1593137386        66 -38.00
# 4                Luena           0      AO  1593137497        64 -11.78
#
#             Lon  Max Temp  Max Temp K  Wind Speed
# City_ID
# 0       -134.97        75      297.16       10.99
# 1        -81.89        82      301.15        1.89
# 2         80.55        37      275.67        3.50
# 3        -57.56        43      279.26        4.10
# 4         19.92        51      283.44        1.90

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Calculate variables
x_axis = weather_pd["Lat"]
y_axis = weather_pd["Max Temp"]
result = time.localtime()
cur_date = f"({result.tm_mon}/{result.tm_mday}/{result.tm_year})"

# Create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="#1f72ac", edgecolors="black",alpha=0.90)


# Set Plot options and display plot
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature {cur_date}")
plt.grid(True)
plt.savefig("output_data/LatvsTemp")
plt.show()

# %% [markdown]
# The code is analyzing the temperatures as you move away from the equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Calculate variables
x_axis = weather_pd["Lat"]
y_axis = weather_pd["Humidity"]
result = time.localtime()
cur_date = f"({result.tm_mon}/{result.tm_mday}/{result.tm_year})"

# Create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="#1f72ac", edgecolors="black",alpha=0.90)


# Set Plot options and display plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Max Temperature {cur_date}")
plt.grid(True)
plt.savefig("output_data/LatvsHumidity")
plt.show()

# %% [markdown]
# The code is analyzing the humidity percentages as you move away from the equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Calculate variables
x_axis = weather_pd["Lat"]
y_axis = weather_pd["Cloudiness"]
result = time.localtime()
cur_date = f"({result.tm_mon}/{result.tm_mday}/{result.tm_year})"

# Create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="#1f72ac", edgecolors="black",alpha=0.90)


# Set Plot options and display plot
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Max Temperature {cur_date}")
plt.grid(True)
plt.savefig("output_data/LatvsCloudy")
plt.show()

# %% [markdown]
# The code is analyzing the cloudiness percent as you move away from the equator.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Calculate variables
x_axis = weather_pd["Lat"]
y_axis = weather_pd["Wind Speed"]
result = time.localtime()
cur_date = f"({result.tm_mon}/{result.tm_mday}/{result.tm_year})"

# Create scatter plot
plt.scatter(x_axis, y_axis, marker="o", facecolors="#1f72ac", edgecolors="black",alpha=0.90)


# Set Plot options and display plot
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Max Temperature {cur_date}")
plt.grid(True)
plt.savefig("output_data/LatvsWind")
plt.show()

# %% [markdown]
# The code is analyzing the wind speed as you move away from the equator.

# %% [markdown]
# ## Linear Regression

# %%
# Create north and south dataframe
weather_north_pd = weather_pd[weather_pd["Lat"] >= 0]
weather_south_pd = weather_pd[weather_pd["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_north_pd["Lat"]
y_axis = weather_north_pd["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(10,40),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")


# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsTempNorth")
plt.show()
# Out:
# The r-squared is: -0.6221194181455177

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_south_pd["Lat"]
y_axis = weather_south_pd["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(-40,35),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")


# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsTempSouth")
plt.show()
# Out:
# The r-squared is: 0.750254891006259

# %% [markdown]
# Maximum temperatures tend to be highest at the equator dropping as you move away in each direction.
# The data seems to be related. The R value is high.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_north_pd["Lat"]
y_axis = weather_north_pd["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsHumidityNorth")
plt.show()
# Out:
# The r-squared is: -0.09464302815662498

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_south_pd["Lat"]
y_axis = weather_south_pd["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(-50,35),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsHumiditySouth")
plt.show()
# Out:
# The r-squared is: 0.05920154665559886

# %% [markdown]
# Humidity percentages are unrelated as you move away unrelated as you move away from the eqautor in each direction.
# This is supported by the low R value.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_north_pd["Lat"]
y_axis = weather_north_pd["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(-50,35),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsHCloudyNorth")
plt.show()
# Out:
# The r-squared is: -0.001086951982814771

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_south_pd["Lat"]
y_axis = weather_south_pd["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(-50,35),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsCloudySouth")
plt.show()
# Out:
# The r-squared is: 0.009587222472552158

# %% [markdown]
# Cloudiness percentages are unrelated as you move away from the eqautor in each direction.
# This is supported by the low R value.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_north_pd["Lat"]
y_axis = weather_north_pd["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(10,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsWindNorth")
plt.show()
# Out:
# The r-squared is: 0.07967595889262095

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calculate variables
x_axis = weather_south_pd["Lat"]
y_axis = weather_south_pd["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create plots
fig, north = plt.subplots() 
line = north.scatter(x_axis, y_axis) 
plt.plot(x_axis,regress_values,"r-")
  
# Add labels
plt.annotate(line_eq,(-50,6),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Display results
print(f"The r-squared is: {rvalue}")
plt.savefig("output_data/LatvsWindSouth")
plt.show()
# Out:
# The r-squared is: -0.05603616170622918

# %% [markdown]
# Wind speed seems unrelated as you move away from the equator in each direction. This is supported by the low R value.
